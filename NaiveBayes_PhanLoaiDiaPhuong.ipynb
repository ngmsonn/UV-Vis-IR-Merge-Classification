# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import accuracy_score, r2_score, confusion_matrix, ConfusionMatrixDisplay, precision_score, f1_score, recall_score
from sklearn.preprocessing import StandardScaler, LabelEncoder, OneHotEncoder
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.svm import LinearSVC, SVC
from sklearn.decomposition import PCA
from sklearn.cross_decomposition import PLSRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.pipeline import Pipeline
from scipy.signal import savgol_filter
from icecream import ic
import random
from sklearn.naive_bayes import GaussianNB

# %%
data = pd.read_csv("/home/sonn/Son/Workspace/UV-Vis_IR_NuocCam/data/data_tunhien.csv")
data.head()
# Out:
#           TenMau  DiaPhuong  NamLayMau Giong  648.5568  652.2841  656.0115  \
# 0  BG.23.Vinh.01  Bắc Giang       2023  Vinh  0.288038  0.314208  0.312564
# 1  BG.23.Vinh.02  Bắc Giang       2023  Vinh  0.334148  0.326995  0.323069
# 2  BG.23.Vinh.04  Bắc Giang       2023  Vinh  0.283841  0.278747  0.278234
# 3  BG.23.Vinh.05  Bắc Giang       2023  Vinh  0.193778  0.195921  0.196467
# 4  BG.23.Vinh.07  Bắc Giang       2023  Vinh  0.225972  0.224173  0.225184
#
#    659.7388  663.4661  667.1935  ...    245     240     235    230    225  \
# 0  0.283867  0.275794  0.293704  ...  2.369   2.630   2.855  2.885  2.676
# 1  0.320567  0.320840  0.319613  ...  2.578   2.808   3.041  3.136  3.004
# 2  0.276258  0.274365  0.272161  ...  5.167  20.000  20.000  5.079  3.885
# 3  0.195541  0.198358  0.194969  ...  3.279   3.597   3.823  3.735  3.400
# 4  0.221635  0.219974  0.218776  ...  3.111   3.447   3.759  3.750  3.401
#
#      220    215    210    205    200
# ...

# %%
tenmau = data["TenMau"]
ma = []
for mau in tenmau:
    ma.append(mau.replace("/", "")[0:2])
data["DiaPhuong"] = ma
y = data['DiaPhuong']
le = LabelEncoder()
y = le.fit_transform(y)

# %%
X = data.iloc[:,4:]
X.head()
# Out:
#    648.5568  652.2841  656.0115  659.7388  663.4661  667.1935  670.9208  \
# 0  0.288038  0.314208  0.312564  0.283867  0.275794  0.293704  0.297450
# 1  0.334148  0.326995  0.323069  0.320567  0.320840  0.319613  0.316539
# 2  0.283841  0.278747  0.278234  0.276258  0.274365  0.272161  0.269835
# 3  0.193778  0.195921  0.196467  0.195541  0.198358  0.194969  0.194062
# 4  0.225972  0.224173  0.225184  0.221635  0.219974  0.218776  0.218363
#
#    674.6481  678.3755  682.1028  ...    245     240     235    230    225  \
# 0  0.278578  0.271924  0.281354  ...  2.369   2.630   2.855  2.885  2.676
# 1  0.312681  0.312266  0.307793  ...  2.578   2.808   3.041  3.136  3.004
# 2  0.266996  0.265478  0.261862  ...  5.167  20.000  20.000  5.079  3.885
# 3  0.193205  0.193799  0.194423  ...  3.279   3.597   3.823  3.735  3.400
# 4  0.217704  0.216161  0.214019  ...  3.111   3.447   3.759  3.750  3.401
#
#      220    215    210    205    200
# 0  2.370  2.081  1.853  1.699  1.620
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((117, 1061), (30, 1061), (117,), (30,))

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# GaussianNB_KhongPCA

# %%
clf = GaussianNB()
clf.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
cmd = ConfusionMatrixDisplay(confusion_matrix(y_test, clf.predict(X_test)))
fig, ax = plt.subplots(figsize=(6,5))
cmd.plot(ax=ax)
plt.show()

# %% [markdown]
# GaussianNB_PCA

# %%
pca = PCA()
clf = GaussianNB()
pipeline = Pipeline(steps=[('pca', pca), ('clf', clf)])
param_grid = {
    'pca__n_components': [2,3,4,5,6,7,8,9,10,12,14],
}
grid = GridSearchCV(pipeline, param_grid, refit = True, verbose = 3) 
grid.fit(X_train, y_train) 
print("\n\n")
ic(grid.best_params_) 
model = grid.best_estimator_
model.fit(X_train, y_train)
print("Accuracy score:",accuracy_score(y_test, model.predict(X_test)))
# Out:
# Fitting 5 folds for each of 11 candidates, totalling 55 fits
# [CV 1/5] END ...............pca__n_components=2;, score=0.542 total time=   0.0s
# [CV 2/5] END ...............pca__n_components=2;, score=0.417 total time=   0.0s
# [CV 3/5] END ...............pca__n_components=2;, score=0.304 total time=   0.0s
# [CV 4/5] END ...............pca__n_components=2;, score=0.391 total time=   0.0s
# [CV 5/5] END ...............pca__n_components=2;, score=0.478 total time=   0.0s
# [CV 1/5] END ...............pca__n_components=3;, score=0.500 total time=   0.0s
# [CV 2/5] END ...............pca__n_components=3;, score=0.458 total time=   0.0s
# [CV 3/5] END ...............pca__n_components=3;, score=0.261 total time=   0.0s
# [CV 4/5] END ...............pca__n_components=3;, score=0.391 total time=   0.0s
# [CV 5/5] END ...............pca__n_components=3;, score=0.478 total time=   0.0s
# [CV 1/5] END ...............pca__n_components=4;, score=0.458 total time=   0.0s
# ...

# %%
cmd = ConfusionMatrixDisplay(confusion_matrix(y_test, model.predict(X_test)))
fig, ax = plt.subplots(figsize=(6,5))
cmd.plot(ax=ax)
plt.show()

# %% [markdown]
# BernoulliNB

# %%
from sklearn.naive_bayes import BernoulliNB

# %%
clf = BernoulliNB()
clf.fit(X_train, y_train)
accuracy_score(y_test, clf.predict(X_test))
# Out:
# 0.3

# %%
cmd = ConfusionMatrixDisplay(confusion_matrix(y_test, clf.predict(X_test)))
fig, ax = plt.subplots(figsize=(6,5))
cmd.plot(ax=ax)
plt.show()

# %% [markdown]
# PCA_BernoulliNB

# %%
pca = PCA()
clf = BernoulliNB()
pipeline = Pipeline(steps=[('pca', pca), ('clf', clf)])
param_grid = {
    'pca__n_components': [2,3,4,5,6,7,8,9,10,12,14],
}
grid = GridSearchCV(pipeline, param_grid, refit = True, verbose = 3) 
grid.fit(X_train, y_train) 
print("\n\n")
ic(grid.best_params_) 
model = grid.best_estimator_
model.fit(X_train, y_train)
print("Accuracy score:",accuracy_score(y_test, model.predict(X_test)))
# Out:
# Fitting 5 folds for each of 11 candidates, totalling 55 fits
# [CV 1/5] END ...............pca__n_components=2;, score=0.375 total time=   0.0s
# [CV 2/5] END ...............pca__n_components=2;, score=0.417 total time=   0.0s
# [CV 3/5] END ...............pca__n_components=2;, score=0.261 total time=   0.0s
# [CV 4/5] END ...............pca__n_components=2;, score=0.478 total time=   0.0s
# [CV 5/5] END ...............pca__n_components=2;, score=0.435 total time=   0.0s
# [CV 1/5] END ...............pca__n_components=3;, score=0.417 total time=   0.0s
# [CV 2/5] END ...............pca__n_components=3;, score=0.417 total time=   0.0s
# [CV 3/5] END ...............pca__n_components=3;, score=0.217 total time=   0.0s
# [CV 4/5] END ...............pca__n_components=3;, score=0.522 total time=   0.0s
# [CV 5/5] END ...............pca__n_components=3;, score=0.435 total time=   0.0s
# [CV 1/5] END ...............pca__n_components=4;, score=0.417 total time=   0.0s
# ...

# %%
accuracy_score(y_test, model.predict(X_test))
# Out:
# 0.7333333333333333

# %%
cmd = ConfusionMatrixDisplay(confusion_matrix(y_test, model.predict(X_test)))
fig, ax = plt.subplots(figsize=(6,5))
cmd.plot(ax=ax)
plt.show()
